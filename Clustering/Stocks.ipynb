# %% [markdown]
# <a href="https://colab.research.google.com/github/iqbalamo93/Clustering/blob/master/Stocks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
url ='https://raw.githubusercontent.com/iqbalamo93/Datasets/master/company-stock-movements-2010-2015-incl.csv'

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#                             Unnamed: 0  2010-01-04  ...  2013-10-28  2013-10-29
# 0                                Apple    0.580000  ...    0.840019  -19.589981
# 1                                  AIG   -0.640002  ...   -0.400002    0.660000
# 2                               Amazon   -2.350006  ...   -1.760009    3.740021
# 3                     American express    0.109997  ...    0.040001    0.540001
# 4                               Boeing    0.459999  ...    1.130005    0.309998
# 5                      Bank of America    0.450000  ...   -0.060000   -0.110000
# 6             British American Tobacco    0.180000  ...    0.330002    1.150001
# 7                                Canon    0.730000  ...    0.090001   -0.110001
# 8                          Caterpillar    0.899997  ...   -0.220001    0.159996
# 9                    Colgate-Palmolive    0.360000  ...    1.070003    1.050003
# 10                      ConocoPhillips    0.809991  ...   -0.020005    0.139999
# ...

# %%
dc=df.iloc[:,1:]

# %%
dc.head()
# Out:
#    2010-01-04  2010-01-05  2010-01-06  ...  2013-10-25  2013-10-28  2013-10-29
# 0    0.580000   -0.220005   -3.409998  ...   -5.359962    0.840019  -19.589981
# 1   -0.640002   -0.650000   -0.210001  ...   -0.040001   -0.400002    0.660000
# 2   -2.350006    1.260009   -2.350006  ...    4.790009   -1.760009    3.740021
# 3    0.109997    0.000000    0.260002  ...    1.849999    0.040001    0.540001
# 4    0.459999    1.770000    1.549999  ...    1.940002    1.130005    0.309998
#
# [5 rows x 963 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import Normalizer
from sklearn.pipeline import make_pipeline

# %%
scaler = Normalizer()
dc = scaler.fit_transform(dc)

# %%
inertia  = []
for x in range(1,10):
  model =  KMeans(n_clusters=x, random_state=1)
  model.fit(dc)
  inertia.append(model.inertia_)
plt.plot(range(1,10),inertia,marker='x')
plt.xlabel('Number of Cluster')
plt.ylabel('Inertia')
plt.show()

# %%
model = KMeans(n_clusters=10)
pipeline = make_pipeline(scaler,model)
pipeline.fit(dc)
# Out:
# Pipeline(memory=None,
#          steps=[('normalizer', Normalizer(copy=True, norm='l2')),
#                 ('kmeans',
#                  KMeans(algorithm='auto', copy_x=True, init='k-means++',
#                         max_iter=300, n_clusters=10, n_init=10, n_jobs=None,
#                         precompute_distances='auto', random_state=None,
#                         tol=0.0001, verbose=0))],
#          verbose=False)

# %%
labels = pipeline.predict(dc)
labels = pd.Series(labels)
data_cros=pd.concat([labels,df.iloc[:,0]],axis=1)

# %%
data_cros.columns=['labels','names']

# %%
data_cros=data_cros.sort_values(by='labels')
data_cros=data_cros.reset_index(drop=True)

# %%
data_cros[data_cros['labels']==0]['names'].unique()
# Out:
# array(['Kimberly-Clark', 'Pepsi', 'Coca Cola', 'Procter Gamble',
#        'Johnson & Johnson', 'Philip Morris', 'Colgate-Palmolive',
#        'Wal-Mart'], dtype=object)

# %%
dic ={}
for x in range(1,10):
  dic[x]=list(data_cros[data_cros['labels']==0]['names'].unique())

# %%
dic
# Out:
# {1: ['Kimberly-Clark',
#   'Pepsi',
#   'Coca Cola',
#   'Procter Gamble',
#   'Johnson & Johnson',
#   'Philip Morris',
#   'Colgate-Palmolive',
#   'Wal-Mart'],
#  2: ['Kimberly-Clark',
#   'Pepsi',
#   'Coca Cola',
#   'Procter Gamble',
#   'Johnson & Johnson',
#   'Philip Morris',
#   'Colgate-Palmolive',
#   'Wal-Mart'],
#  3: ['Kimberly-Clark',
#   'Pepsi',
#   'Coca Cola',
#   'Procter Gamble',
#   'Johnson & Johnson',
#   'Philip Morris',
#   'Colgate-Palmolive',
#   'Wal-Mart'],
#  4: ['Kimberly-Clark',
#   'Pepsi',
#   'Coca Cola',
#   'Procter Gamble',
#   'Johnson & Johnson',
#   'Philip Morris',
#   'Colgate-Palmolive',
#   'Wal-Mart'],
#  5: ['Kimberly-Clark',
#   'Pepsi',
#   'Coca Cola',
#   'Procter Gamble',
#   'Johnson & Johnson',
#   'Philip Morris',
#   'Colgate-Palmolive',
#   'Wal-Mart'],
#  6: ['Kimberly-Clark',
#   'Pepsi',
#   'Coca Cola',
#   'Procter Gamble',
#   'Johnson & Johnson',
#   'Philip Morris',
#   'Colgate-Palmolive',
#   'Wal-Mart'],
# ...
